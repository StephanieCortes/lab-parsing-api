# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
import re
import json
import requests
import urllib
import pandas as pd
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=84&sort=popularity'

# your code here
request=urllib.request.urlopen(url)
data=json.load(request)
flattened_data=pd.json_normalize(data)
flattened_data1=pd.json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   S3721U00L-K11                          Veste d'hiver - navy blue
# 1   M5921I0I5-Q11                           MENZIP - Pullover - noir
# 2   M6O31E00W-Q11            SUPER FLICK EYELINER - Eyeliner - black
# 3   RED31J01X-S11  MIRACLE COMPLEXION SPONGE + CASE - Beautyblend...
# 4   DP621N00T-Q11                               Jeans Skinny - black
# ..            ...                                                ...
# 79  ON321E1OS-Q11                          ONLAMAZE - Blouse - black
# 80  LO951H0HM-Q11                   EVENING BAG - Sac à main - black
# 81  M9121A1TH-K11         BOREAL6 - Pantalon de costume - royal blue
# 82  M6O31E019-J11     POWDER MATTE LIPSTICK - Rouge à lèvres - teddy
# 83  F5351G029-B11                                    Écharpe - beige
#
#                        sizes  \
# 0          [XS, S, M, L, XL]
# 1              [XS, S, M, L]
# 2                         []
# 3                         []
# 4               [46, 48, 50]
# ..                       ...
# 79             [XS, S, M, L]
# 80                [One Size]
# 81  [34, 36, 38, 40, 42, 44]
# 82                        []
# 83                [One Size]
#
#                                               url_key  \
# 0       schott-veste-dhiver-blue-marine-s3721u00l-k11
# 1           morgan-menzip-pullover-noir-m5921i0i5-q11
# 2   make-up-revolution-super-flick-eyeliner-eyelin...
# 3   real-techniques-miracle-complexion-sponge-case...
# 4   dorothy-perkins-curve-jeans-skinny-black-dp621...
# ..                                                ...
# 79           only-onlamaze-blouse-black-on321e1os-q11
# 80  love-moschino-evening-bag-sac-a-main-black-lo9...
# 81        mango-boreal-chino-royal-blue-m9121a1th-k11
# 82  make-up-revolution-powder-matte-lipstick-rouge...
# 83                  fraas-echarpe-beige-f5351g029-b11
#
#                                                 media             brand_name  \
# 0   [{'path': 'spp-media-p1/92806187adaa352aa39292...                 Schott
# 1   [{'path': 'spp-media-p1/3f16af511c3931378c54ab...                 Morgan
# 2   [{'path': 'spp-media-p1/1c5b17a5b67833058fae87...     Make up Revolution
# 3   [{'path': 'spp-media-p1/28eaa7b7d23331a3a96cf9...        Real Techniques
# 4   [{'path': 'spp-media-p1/a0e9bcd86f793ed8b00ed7...  Dorothy Perkins Curve
# ..                                                ...                    ...
# 79  [{'path': 'spp-media-p1/080d8c77bf7e36bf9cd477...                   ONLY
# 80  [{'path': 'spp-media-p1/c8def9b150db33dabbd7f1...          Love Moschino
# 81  [{'path': 'spp-media-p1/3879080ee6f039a7bf3cfd...                  Mango
# 82  [{'path': 'spp-media-p1/a6c1787c0fd334c69dba84...     Make up Revolution
# 83  [{'path': 'spp-media-p1/ceff633e5db136f5995ee0...                  Fraas
#
#     is_premium family_articles  \
# 0        False              []
# 1        False              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-37%', 'tra...      clothing
# 1   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 2   [{'key': 'discountRate', 'value': '-20%', 'tra...        beauty
# 3   [{'key': 'discountRate', 'value': '-20%', 'tra...        beauty
# 4   [{'key': 'discountRate', 'value': '-35%', 'tra...      clothing
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-50%', 'tra...      clothing
# 80  [{'key': 'discountRate', 'value': '-40%', 'tra...   accessoires
# 81  [{'key': 'discountRate', 'value': '-35%', 'tra...      clothing
# 82  [{'key': 'discountRate', 'value': '-20%', 'tra...        beauty
# 83  [{'key': 'discountRate', 'value': '-20%', 'tra...   accessoires
#
#                                     delivery_promises price.original  \
# 0                                                  []       249,00 €
# 1   [{'key': 'slow_delivery_flag', 'label': 'Livra...        24,95 €
# 2                                                  []         5,95 €
# 3                                                  []         7,95 €
# 4                                                  []        35,99 €
# ..                                                ...            ...
# 79                                                 []        17,99 €
# 80                                                 []       149,95 €
# 81                                                 []        39,99 €
# 82                                                 []         5,95 €
# 83  [{'key': 'slow_delivery_flag', 'label': 'Livra...        29,95 €
#
#    price.promotional  price.has_different_prices  \
# 0           157,50 €                       False
# 1            19,95 €                       False
# 2             4,75 €                       False
# 3             6,35 €                       False
# 4            23,49 €                       False
# ..               ...                         ...
# 79            8,99 €                       False
# 80           89,95 €                       False
# 81           25,99 €                       False
# 82            4,75 €                       False
# 83           23,95 €                       False
#
#     price.has_different_original_prices  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 79                                False
# 80                                False
# 81                                False
# 82                                False
# 83                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only  amount   price.base_price
# 0                                       False     NaN                NaN
# 1                                       False     NaN                NaN
# 2                                       False  4,5 ml  105,56 € / 100 ml
# 3                                       False     NaN                NaN
# 4                                       False     NaN                NaN
# ..                                        ...     ...                ...
# 79                                      False     NaN                NaN
# 80                                      False     NaN                NaN
# 81                                      False     NaN                NaN
# 82                                      False   3,5 g   135,71 € / 100 g
# 83                                      False     NaN                NaN
#
# [84 rows x 19 columns]

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
#request = urllib.request.urlopen(url)
#data = json.load(request)
#data.keys()
#json_url = urllib.request.urlopen(url)
#results = json.loads(json_url.read())

# Get the total number of pages
total_pages=results['pagination']['page_count']
print(total_pages)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-03de11c35e8a> in <module>
#       7
#       8 # Get the total number of pages
# ----> 9 total_pages=results['pagination']['page_count']
#      10 print(total_pages)
#      11
#
# NameError: name 'results' is not defined

# %%
# Your code
df=pd.DataFrame()
for i in range(2):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort-sale'
    request = urllib.request.urlopen(url)
    data = json.load(request)
    flattened_data = pd.json_normalize(data)
    flattened_data1 = pd.json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
#                                                             name  \
# sku
# M6O31E004-T11  EYESHADOW PALETTE FOREVER FLAWLESS ALLURE - Pa...
# MJ331E01X-B11  INSTANT ANTI-AGE EFFECT CONCEALER - Correcteur...
# NY631F00V-T18  ULTIMATE SHADOW PALETTE - Palette fard à paupi...
# M6O31E017-T11  EYESHADOW PALETTE RELOADED - Palette fard à pa...
# PU111A0HA-A11  CALI SPORT - Baskets basses - white/black/high...
# ...                                                          ...
# LO951H0HM-Q11                   EVENING BAG - Sac à main - black
# M9121A1TH-K11         BOREAL6 - Pantalon de costume - royal blue
# NI111A0D1-A15  ZOOM 2K - Baskets basses - platinum tint/hyper...
# M6O31E019-J11     POWDER MATTE LIPSTICK - Rouge à lèvres - teddy
# F5351G029-B11                                    Écharpe - beige
#
#                                                            sizes  \
# sku
# M6O31E004-T11                                                 []
# MJ331E01X-B11                                                 []
# NY631F00V-T18                                                 []
# M6O31E017-T11                                                 []
# PU111A0HA-A11         [36, 37, 37.5, 38, 38.5, 39, 40, 40.5, 41]
# ...                                                          ...
# LO951H0HM-Q11                                         [One Size]
# M9121A1TH-K11                           [34, 36, 38, 40, 42, 44]
# NI111A0D1-A15  [36.5, 37.5, 38, 38.5, 39, 40, 40.5, 41, 42, 4...
# M6O31E019-J11                                                 []
# F5351G029-B11                                         [One Size]
#
#                                                          url_key  \
# sku
# M6O31E004-T11  make-up-revolution-eyeshadow-palette-forever-f...
# MJ331E01X-B11  maybelline-new-york-instant-anti-age-effect-co...
# NY631F00V-T18  nyx-professional-makeup-ultimate-shadow-palett...
# M6O31E017-T11  make-up-revolution-eyeshadow-palette-reloaded-...
# PU111A0HA-A11  puma-cali-sport-baskets-basses-whiteblackhigh-...
# ...                                                          ...
# LO951H0HM-Q11  love-moschino-evening-bag-sac-a-main-black-lo9...
# M9121A1TH-K11        mango-boreal-chino-royal-blue-m9121a1th-k11
# NI111A0D1-A15  nike-sportswear-zoom-2k-baskets-basses-ni111a0...
# M6O31E019-J11  make-up-revolution-powder-matte-lipstick-rouge...
# F5351G029-B11                  fraas-echarpe-beige-f5351g029-b11
#
#                                                            media  \
# sku
# M6O31E004-T11  [{'path': 'spp-media-p1/5d69451a502d30128f8718...
# MJ331E01X-B11  [{'path': 'spp-media-p1/7c6a17404747390faa8605...
# NY631F00V-T18  [{'path': 'spp-media-p1/8095dc97aafa35768e0bdf...
# M6O31E017-T11  [{'path': 'spp-media-p1/57b41deed9b234c78d4880...
# PU111A0HA-A11  [{'path': 'spp-media-p1/a29ba350ef223255a741df...
# ...                                                          ...
# LO951H0HM-Q11  [{'path': 'spp-media-p1/c8def9b150db33dabbd7f1...
# M9121A1TH-K11  [{'path': 'spp-media-p1/3879080ee6f039a7bf3cfd...
# NI111A0D1-A15  [{'path': 'spp-media-p1/9688b3c3b7053a73ad13b4...
# M6O31E019-J11  [{'path': 'spp-media-p1/a6c1787c0fd334c69dba84...
# F5351G029-B11  [{'path': 'spp-media-p1/ceff633e5db136f5995ee0...
#
#                             brand_name  is_premium family_articles  \
# sku
# M6O31E004-T11       Make up Revolution       False              []
# MJ331E01X-B11      Maybelline New York       False              []
# NY631F00V-T18  Nyx Professional Makeup       False              []
# M6O31E017-T11       Make up Revolution       False              []
# PU111A0HA-A11                     Puma       False              []
# ...                                ...         ...             ...
# LO951H0HM-Q11            Love Moschino       False              []
# M9121A1TH-K11                    Mango       False              []
# NI111A0D1-A15          Nike Sportswear       False              []
# M6O31E019-J11       Make up Revolution       False              []
# F5351G029-B11                    Fraas       False              []
#
#                                                            flags  \
# sku
# M6O31E004-T11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# MJ331E01X-B11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# NY631F00V-T18  [{'key': 'discountRate', 'value': '-20%', 'tra...
# M6O31E017-T11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# PU111A0HA-A11  [{'key': 'discountRate', 'value': 'Jusqu’à -50...
# ...                                                          ...
# LO951H0HM-Q11  [{'key': 'discountRate', 'value': '-40%', 'tra...
# M9121A1TH-K11  [{'key': 'discountRate', 'value': '-35%', 'tra...
# NI111A0D1-A15  [{'key': 'discountRate', 'value': '-30%', 'tra...
# M6O31E019-J11  [{'key': 'discountRate', 'value': '-20%', 'tra...
# F5351G029-B11  [{'key': 'discountRate', 'value': '-20%', 'tra...
#
#               product_group   amount  \
# sku
# M6O31E004-T11        beauty   19,8 g
# MJ331E01X-B11        beauty   6,8 ml
# NY631F00V-T18        beauty  13,28 g
# M6O31E017-T11        beauty   16,5 g
# PU111A0HA-A11          shoe      NaN
# ...                     ...      ...
# LO951H0HM-Q11   accessoires      NaN
# M9121A1TH-K11      clothing      NaN
# NI111A0D1-A15          shoe      NaN
# M6O31E019-J11        beauty    3,5 g
# F5351G029-B11   accessoires      NaN
#
#                                                delivery_promises  \
# sku
# M6O31E004-T11                                                 []
# MJ331E01X-B11                                                 []
# NY631F00V-T18                                                 []
# M6O31E017-T11                                                 []
# PU111A0HA-A11                                                 []
# ...                                                          ...
# LO951H0HM-Q11                                                 []
# M9121A1TH-K11                                                 []
# NI111A0D1-A15                                                 []
# M6O31E019-J11                                                 []
# F5351G029-B11  [{'key': 'slow_delivery_flag', 'label': 'Livra...
#
#               price.original price.promotional  price.has_different_prices  \
# sku
# M6O31E004-T11        11,95 €            9,60 €                       False
# MJ331E01X-B11         9,95 €            7,95 €                       False
# NY631F00V-T18        17,95 €           14,40 €                       False
# M6O31E017-T11         5,95 €            4,75 €                       False
# PU111A0HA-A11        94,95 €           47,45 €                        True
# ...                      ...               ...                         ...
# LO951H0HM-Q11       149,95 €           89,95 €                       False
# M9121A1TH-K11        39,99 €           25,99 €                       False
# NI111A0D1-A15        84,95 €           59,45 €                       False
# M6O31E019-J11         5,95 €            4,75 €                       False
# F5351G029-B11        29,95 €           23,95 €                       False
#
#                price.has_different_original_prices  \
# sku
# M6O31E004-T11                                False
# MJ331E01X-B11                                False
# NY631F00V-T18                                False
# M6O31E017-T11                                False
# PU111A0HA-A11                                False
# ...                                            ...
# LO951H0HM-Q11                                False
# M9121A1TH-K11                                False
# NI111A0D1-A15                                False
# M6O31E019-J11                                False
# F5351G029-B11                                False
#
#                price.has_different_promotional_prices  \
# sku
# M6O31E004-T11                                   False
# MJ331E01X-B11                                   False
# NY631F00V-T18                                   False
# M6O31E017-T11                                   False
# PU111A0HA-A11                                    True
# ...                                               ...
# LO951H0HM-Q11                                   False
# M9121A1TH-K11                                   False
# NI111A0D1-A15                                   False
# M6O31E019-J11                                   False
# F5351G029-B11                                   False
#
#                price.has_discount_on_selected_sizes_only   price.base_price  \
# sku
# M6O31E004-T11                                      False                NaN
# MJ331E01X-B11                                      False  116,91 € / 100 ml
# NY631F00V-T18                                      False                NaN
# M6O31E017-T11                                      False                NaN
# PU111A0HA-A11                                      False                NaN
# ...                                                  ...                ...
# LO951H0HM-Q11                                      False                NaN
# M9121A1TH-K11                                      False                NaN
# NI111A0D1-A15                                      False                NaN
# M6O31E019-J11                                      False   135,71 € / 100 g
# F5351G029-B11                                      False                NaN
#
#               outfits
# sku
# M6O31E004-T11     NaN
# MJ331E01X-B11     NaN
# NY631F00V-T18     NaN
# M6O31E017-T11     NaN
# PU111A0HA-A11     NaN
# ...               ...
# LO951H0HM-Q11     NaN
# M9121A1TH-K11     NaN
# NI111A0D1-A15     NaN
# M6O31E019-J11     NaN
# F5351G029-B11     NaN
#
# [168 rows x 19 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
